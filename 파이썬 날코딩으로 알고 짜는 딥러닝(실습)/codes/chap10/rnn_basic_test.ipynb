# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/Academy.ALZZA-master/Academy.ALZZA-master/codes/chap10/rnn_basic_model.ipynb"
# %run "/content/drive/MyDrive/Colab Notebooks/Academy.ALZZA-master/Academy.ALZZA-master/codes/chap10/dataset_automata.ipynb"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ad = AutomataDataset()

am_4  = RnnBasicModel('am_4',  ad, ['rnn', {'recur_size':4,  'outseq':False}])
am_16 = RnnBasicModel('am_16', ad, ['rnn', {'recur_size':16, 'outseq':False}])
am_64 = RnnBasicModel('am_64', ad, ['rnn', {'recur_size':64, 'outseq':False}])

# %%
am_4.exec_all(epoch_count=10, report=2)
# Out:
# Model am_4 train started:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-000348ff3ca5> in <module>()
# ----> 1 am_4.exec_all(epoch_count=10, report=2)
#
# <ipython-input-2-2f632d17b89a> in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt, show_params)
#       9                  report=0, show_cnt=3, show_params=False):
#      10         super(CnnRegModel, self).exec_all(epoch_count, batch_size,
# ---> 11                                      learning_rate, report, show_cnt)
#      12         if show_params: self.show_param_dist()
#
# <ipython-input-2-693dfcc67650> in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt)
#      11     def exec_all(self, epoch_count=10, batch_size=10, learning_rate=0.001,
#      12                  report=0, show_cnt=3):
# ---> 13         self.train(epoch_count, batch_size, learning_rate, report)
#      14         self.test()
#      15         if show_cnt > 0: self.visualize(show_cnt)
#
# <ipython-input-2-7517b0c62ca7> in mlp_model_train(self, epoch_count, batch_size, learning_rate, report)
#      12         self.dataset.shuffle_train_data(batch_size*batch_count)
#      13         for n in range(batch_count):
# ---> 14             trX, trY = self.dataset.get_train_data(batch_size, n)
#      15             cost, acc = self.train_step(trX, trY)
#      16             costs.append(cost)
#
# <ipython-input-2-595394d24600> in automata_get_train_data(self, batch_size, nth)
#       1 def automata_get_train_data(self, batch_size, nth):
# ----> 2     return automata_generate_data(batch_size)
#       3
#       4 def automata_get_validate_data(self, count):
#       5     return automata_generate_data(count)
#
# <ipython-input-2-595394d24600> in automata_generate_data(count)
#      16
#      17         if is_correct:
# ---> 18             sent = automata_generate_sent()
#      19         else:
#      20             while True:
#
# <ipython-input-2-cc62b691f40c> in automata_generate_sent()
#       2     while True:
#       3         try:
# ----> 4             sent = automata_gen_node(S, 0)
#       5             if len(sent) >= MAX_LENGTH: continue
#       6             if len(sent) <= MIN_LENGTH: continue
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      20             sent += term[pos]
#      21         else:
# ---> 22             sent += automata_gen_node(term, depth+1)
#      23     return sent
#
# <ipython-input-2-cc62b691f40c> in automata_gen_node(node, depth)
#      13     if node not in RULES: assert 0
#      14     rules = RULES[node]
# ---> 15     nth = np.random.randint(len(rules))
#      16     sent = ''
#      17     for term in rules[nth]:
#
# KeyboardInterrupt:

# %%
am_16.exec_all(epoch_count=10, report=2)
# Out:
# Model am_16 train started:
#     Epoch 2: cost=0.677, accuracy=0.575/0.670 (21/21 secs)
#     Epoch 4: cost=0.645, accuracy=0.624/0.640 (20/41 secs)
#     Epoch 6: cost=0.616, accuracy=0.666/0.710 (21/62 secs)
#     Epoch 8: cost=0.504, accuracy=0.779/0.710 (20/82 secs)
#     Epoch 10: cost=0.577, accuracy=0.768/0.900 (20/102 secs)
# Model am_16 train ended in 102 secs:
# Model am_16 test report: accuracy = 0.820, (0 secs)
#
# Model am_16 Visualization
# 8w2+h5afg3m: 잘못된 패턴 => 탈락추정(0.09) : O
# nj/172/007/4-r*uh*92: 올바른 패턴 => 합격추정(0.78) : O
# 344t1583-p6: 잘못된 패턴 => 탈락추정(0.22) : O

# %%
am_64.exec_all(epoch_count=10, report=2)
# Out:
# Model am_64 train started:
#     Epoch 2: cost=0.691, accuracy=0.523/0.530 (28/28 secs)
#     Epoch 4: cost=0.658, accuracy=0.588/0.640 (27/55 secs)
#     Epoch 6: cost=0.377, accuracy=0.847/0.930 (28/83 secs)
#     Epoch 8: cost=0.306, accuracy=0.885/0.830 (28/111 secs)
#     Epoch 10: cost=0.331, accuracy=0.874/0.940 (27/138 secs)
# Model am_64 train ended in 138 secs:
# Model am_64 test report: accuracy = 0.881, (0 secs)
#
# Model am_64 Visualization
# cp*(v9n7/zbx*(q+f5/0g9)): 잘못된 패턴 => 탈락추정(0.01) : O
# ((tw/t)+suy5+e*a)/62+0: 올바른 패턴 => 합격추정(0.88) : O
# a1wj-3411160*78f*394019x5+1/66/x: 잘못된 패턴 => 탈락추정(0.09) : O

# %%
am_64_drop = RnnBasicModel('am_64_drop', ad,
        [['rnn', {'recur_size':64, 'outseq':False}],
         ['dropout', {'keep_prob':0.5}]])
am_64_drop.exec_all(epoch_count=10, report=2)
# Out:
# Model am_64_drop train started:
#     Epoch 2: cost=0.692, accuracy=0.523/0.540 (24/24 secs)
#     Epoch 4: cost=0.680, accuracy=0.594/0.530 (23/47 secs)
#     Epoch 6: cost=0.602, accuracy=0.690/0.820 (24/71 secs)
#     Epoch 8: cost=0.433, accuracy=0.819/0.830 (24/95 secs)
#     Epoch 10: cost=0.351, accuracy=0.870/0.840 (24/119 secs)
# Model am_64_drop train ended in 119 secs:
# Model am_64_drop test report: accuracy = 0.894, (0 secs)
#
# Model am_64_drop Visualization
# m4k5+v73/330269*485*988)/8: 잘못된 패턴 => 합격추정(0.77) : X
# 223-((p*4)*(981*(o+p)))*22*n5+x-t+71: 올바른 패턴 => 합격추정(0.61) : O
# 6+d*jqm/(994u: 잘못된 패턴 => 탈락추정(0.29) : O
