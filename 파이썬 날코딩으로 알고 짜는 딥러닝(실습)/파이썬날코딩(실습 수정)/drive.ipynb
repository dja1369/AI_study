# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
abalone = '/content/drive/MyDrive/Colab Notebooks/딥러닝/abalone.csv'
pulsar_stars = '/content/drive/MyDrive/Colab Notebooks/딥러닝/pulsar_stars.csv'
faults = '/content/drive/MyDrive/Colab Notebooks/딥러닝/faults.csv'
