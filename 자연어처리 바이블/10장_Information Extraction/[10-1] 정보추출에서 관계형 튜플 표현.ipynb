# %% [markdown]
# # **실습 10-1**

# %%
# [표11-1]의 예를 바탕으로 한 구조화된 데이터
locs = [('동서대학교', 'In', '한국'),
        ('도쿄대학교', 'In', '일본'),
        ('롯데 자이언츠', 'In', '일본'),
        ('뉴욕 양키즈', 'In', '미국'),
        ('맨체스터 유나이티드', 'In', '영국'),
        ('애플', 'In', '미국')]

# %%
query = []

for (e1, rel, e2) in locs:
  if e2=='미국':
    query.append(e1)
    query.append(e2)

print(query)
# Out:
# ['뉴욕 양키즈', '미국', '애플', '미국']
